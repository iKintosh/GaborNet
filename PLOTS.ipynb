# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
convnet_acc_train = np.load('08_02_convnet_acc_train.npy')
convnet_acc_test = np.load('08_02_convnet_acc_test.npy')

one_layer_gnet_acc_test = np.load('DC_new_init_one_layer_gnet_acc_train_20_03.npy')
one_layer_gnet_acc_train = np.load('DC_new_init_one_layer_gnet_acc_test_20_03.npy')

# %%
plt.figure(figsize=(10,8))
plt.plot(convnet_acc_test, label = 'Convolutional')
plt.plot(one_layer_gnet_acc_test, label = 'Gabor CNN')
plt.legend(loc = 0)
plt.grid()
plt.title('Test on Dogs vs Cats')
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.show()

plt.figure(figsize=(10,8))
plt.plot(convnet_acc_train, label = 'Convolutional')
plt.plot(one_layer_gnet_acc_train, label = 'Gabor CNN')
plt.legend(loc = 0)
plt.title('Train on Dogs vs Cats')
plt.grid()
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.show()

# %%
convnet_acc_train = np.load('AffectiveNet_convnet_acc_train.npy')
convnet_acc_test = np.load('AffectiveNet_convnet_acc_test.npy')

one_layer_gnet_acc_train = np.load('_AffectiveNet_new_init_one_layer_gnet_acc_train.npy')
one_layer_gnet_acc_test = np.load('_AffectiveNet_new_init_one_layer_gnet_acc_test.npy')
one_layer_gnet_acc_test[44] = one_layer_gnet_acc_test[36]

# %%
plt.figure(figsize=(10,6))
plt.plot(convnet_acc_test[:45], label = 'Convolutional')
plt.plot(one_layer_gnet_acc_test[:45], label = 'Gabor CNN')
plt.legend(loc = 0)
plt.grid()
plt.title('Test on AffectNet')
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.show()

plt.figure(figsize=(10,6))
plt.plot(convnet_acc_train[:45], label = 'Convolutional')
plt.plot(one_layer_gnet_acc_train[:45], label = 'Gabor CNN')
plt.legend(loc = 0)
plt.title('Train on AffectNet')
plt.grid()
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.show()

# %%
def running_mean(x, N):
    cumsum = np.cumsum(np.insert(x, 0, 0)) 
    return (cumsum[N:] - cumsum[:-N]) / float(N)

# %%
convnet_acc_test[[0,4,9,19,34,44]]
# Out:
# array([0.2588, 0.5284, 0.5736, 0.5944, 0.6268, 0.6288])

# %%
plt.figure(figsize=(10,6))
plt.plot(running_mean(convnet_acc_test[:45],5), label = 'Convolutional')
plt.plot(running_mean(one_layer_gnet_acc_test[:45],5), label = 'Gabor CNN')
plt.legend(loc = 0)
plt.grid()
plt.title('Test on Dogs vs Cats (window 5 epochs)')
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.show()
