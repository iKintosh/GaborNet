# %%
import torch.nn as nn
import torch
import os
import random
from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch
import numpy as np
import cv2
import matplotlib.pyplot as plt
from numpy.random import rand, randn
import torchvision.datasets as dset
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
from DogsCatsDataloader import DogsCatsDataset
from torchvision import transforms, utils
from torch.utils.data import DataLoader
from GaborLayers import GaborConv2d

# %%
transform = transforms.Compose([transforms.ToPILImage(), transforms.Resize((256,256)), transforms.ToTensor(), transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

# %%
train_set = DogsCatsDataset(root_dir='D:\\Dogs vs Cats\\train', transform=transform)
test_set = DogsCatsDataset(root_dir='D:\\Dogs vs Cats\\validation', transform=transform)

# %%
train = DataLoader(train_set, batch_size=64, shuffle=True, num_workers=4)
test = DataLoader(test_set, batch_size=64, shuffle=True, num_workers=4)

# %%
len(train)
# Out:
# 283

# %%
one_layer_gnet_acc_train = []
one_layer_gnet_loss_train = []
one_layer_gnet_acc_test = []
one_layer_gnet_loss_test = []

two_layer_gnet_acc_train = []
two_layer_gnet_loss_train = []
two_layer_gnet_acc_test = []
two_layer_gnet_loss_test = []

convnet_acc_train = []
convnet_loss_train = []
convnet_acc_test = []
convnet_loss_test = []

one_layer_cgnet_acc_train = []
one_layer_cgnet_loss_train = []
one_layer_cgnet_acc_test = []
one_layer_cgnet_loss_test = []

two_layer_cgnet_acc_train = []
two_layer_cgnet_loss_train = []
two_layer_cgnet_acc_test = []
two_layer_cgnet_loss_test = []

# %%
class GaborNet_one_layer(nn.Module):
    def __init__(self):
        super(GaborNet_one_layer, self).__init__()
        self.g1 = GaborConv2d(3, 32, kernel_size=(15,15), stride=1)
        self.c1 = nn.Conv2d(32, 64, kernel_size=(3,3), stride=1)
        self.c2 = nn.Conv2d(64, 128, kernel_size=(3,3), stride=1)
        self.c3 = nn.Conv2d(128, 128, kernel_size=(3,3), stride=1)
        self.c4 = nn.Conv2d(128, 128, kernel_size=(3,3), stride=1)
        self.fc1 = nn.Linear(128*5*5, 128)
        self.fc2 = nn.Linear(128, 128)
        self.fc3 = nn.Linear(128,2)

    def forward(self, x):
        x = F.max_pool2d(F.relu(self.g1(x)), kernel_size=2)
        x = nn.Dropout2d()(x)
        x = F.max_pool2d(F.relu(self.c1(x)), kernel_size=2)
        x = nn.Dropout2d()(x)
        x = F.max_pool2d(F.relu(self.c2(x)), kernel_size=2)
        x = nn.Dropout2d()(x)
        x = F.max_pool2d(F.relu(self.c3(x)), kernel_size=2)
        x = nn.Dropout2d()(x)
        x = F.max_pool2d(F.relu(self.c4(x)), kernel_size=2)
        x = nn.Dropout2d()(x)
        x = x.view(-1, 128*5*5)
        x = F.relu(self.fc1(x))
        x = nn.Dropout()(x)
        x = F.relu(self.fc2(x))
        x = nn.Dropout()(x)
        x = self.fc3(x)
        return x

def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        nn.init.xavier_uniform_(m.weight.data)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
net = GaborNet_one_layer().to(device)
net.apply(weights_init)
print(net)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters())
# Out:
# cuda:0
# GaborNet_one_layer(
#   (g1): GaborConv2d(3, 32, kernel_size=(15, 15), stride=(1, 1), bias=False)
#   (c1): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#   (c2): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1))
#   (c3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#   (c4): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#   (fc1): Linear(in_features=3200, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=128, bias=True)
#   (fc3): Linear(in_features=128, out_features=2, bias=True)
# )

# %%
for epoch in range(100):

    running_loss = 0.0
    correct = 0
    net.train()
    for i, data in enumerate(train, 0):
        # get the inputs
        inputs, labels = data['image'], data['target']

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = net(inputs.to(device))
        loss = criterion(outputs, labels.to(device))
        loss.backward()
        optimizer.step()
        pred = outputs.max(1, keepdim=True)[1].to('cpu')
        correct += pred.eq(labels.view_as(pred)).sum().item()

        # print statistics
        running_loss += loss.item()
    print('[%d] train_acc: %.3f train_loss: %.3f' %(epoch + 1, correct/len(train_set), running_loss/len(train_set))) 
    one_layer_gnet_acc_train.append(correct/len(train_set))
    one_layer_gnet_loss_train.append(running_loss/len(train_set)) 
    
    running_loss = 0.0
    correct = 0
    with torch.no_grad():
        net.eval()
        for i, data in enumerate(test, 0):
            # get the inputs
            inputs, labels = data['image'], data['target']

            # forward + backward + optimize
            outputs = net(inputs.to(device))
            loss = criterion(outputs, labels.to(device))

            pred = outputs.max(1, keepdim=True)[1].to('cpu')
            correct += pred.eq(labels.view_as(pred)).sum().item()
            running_loss += loss.item()
    print('[%d] test_acc: %.3f test_loss: %.3f' %(epoch + 1, correct/len(test_set), running_loss/len(test_set)))
    one_layer_gnet_acc_test.append(correct/len(test_set))
    one_layer_gnet_loss_test.append(running_loss/len(test_set))      

print('Finished Training')

np.save('one_layer_gnet_acc_train.npy', one_layer_gnet_acc_train)
np.save('one_layer_gnet_loss_train.npy', one_layer_gnet_loss_train)
np.save('one_layer_gnet_acc_test.npy', one_layer_gnet_acc_test)
np.save('one_layer_gnet_loss_test.npy', one_layer_gnet_loss_test)


'''for epoch in range(100):  # loop over the dataset multiple times
    running_loss = 0.0
    for i in range(int(EMONEW.lenght()/BATCH_SIZE)):
        net.train()
        # get the inputs
        inputs, labels = EMONEW.get_batch(BATCH_SIZE)
        inputs = torch.Tensor(inputs).to(device)/255
        labels = torch.Tensor(labels).max(1)[1].type(torch.LongTensor).to(device)
        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()

        # print statistics
        running_loss += loss.item()
        if i%10 == 9:
            print('[%d] loss: %.3f' %(epoch + 1, running_loss / (10*BATCH_SIZE)))
            running_loss = 0.0
            
        optimizer.step()
        
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for i in range(int(EMONEW.lenght(False)/BATCH_SIZE)):
            inputs, labels = EMONEW.get_batch(BATCH_SIZE, False)
            inputs = torch.Tensor(inputs).to(device)/255
            outputs = net(inputs)
            labels = torch.Tensor(labels).max(1)[1].type(torch.LongTensor).to(device)
            test_loss += criterion(outputs, labels) # sum up batch loss
            pred = outputs.max(1, keepdim=True)[1] # get the index of the max log-probability
            correct += pred.eq(labels.view_as(pred)).sum().item()

    test_loss /= EMONEW.lenght(False)
    print('\n[{}] Test set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(epoch+1,
        test_loss, correct, EMONEW.lenght(False),
        100. * correct / EMONEW.lenght(False)))
    S_gabor_test_acc.append(correct / EMONEW.lenght(False))
print('Finished Training')'''
# Out:
# [1] train_acc: 0.500 train_loss: 0.011
# [1] test_acc: 0.506 test_loss: 0.011
# [2] train_acc: 0.503 train_loss: 0.011
# [2] test_acc: 0.510 test_loss: 0.011
# [3] train_acc: 0.508 train_loss: 0.011
# [3] test_acc: 0.507 test_loss: 0.011
# [4] train_acc: 0.515 train_loss: 0.011
# [4] test_acc: 0.514 test_loss: 0.011
# [5] train_acc: 0.522 train_loss: 0.011
# [5] test_acc: 0.514 test_loss: 0.011
# [6] train_acc: 0.525 train_loss: 0.011
# [6] test_acc: 0.526 test_loss: 0.011
# [7] train_acc: 0.533 train_loss: 0.011
# [7] test_acc: 0.555 test_loss: 0.011
# [8] train_acc: 0.563 train_loss: 0.011
# [8] test_acc: 0.566 test_loss: 0.011
# [9] train_acc: 0.570 train_loss: 0.011
# [9] test_acc: 0.579 test_loss: 0.011
# [10] train_acc: 0.580 train_loss: 0.011
# [10] test_acc: 0.591 test_loss: 0.010
# [11] train_acc: 0.600 train_loss: 0.010
# [11] test_acc: 0.601 test_loss: 0.011
# [12] train_acc: 0.608 train_loss: 0.010
# [12] test_acc: 0.589 test_loss: 0.011
# [13] train_acc: 0.615 train_loss: 0.010
# [13] test_acc: 0.605 test_loss: 0.010
# [14] train_acc: 0.619 train_loss: 0.010
# [14] test_acc: 0.628 test_loss: 0.010
# [15] train_acc: 0.627 train_loss: 0.010
# [15] test_acc: 0.626 test_loss: 0.010
# [16] train_acc: 0.628 train_loss: 0.010
# [16] test_acc: 0.627 test_loss: 0.010
# [17] train_acc: 0.632 train_loss: 0.010
# [17] test_acc: 0.632 test_loss: 0.010
# [18] train_acc: 0.643 train_loss: 0.010
# [18] test_acc: 0.643 test_loss: 0.010
# [19] train_acc: 0.641 train_loss: 0.010
# [19] test_acc: 0.653 test_loss: 0.010
# [20] train_acc: 0.647 train_loss: 0.010
# [20] test_acc: 0.648 test_loss: 0.010
# [21] train_acc: 0.648 train_loss: 0.010
# [21] test_acc: 0.657 test_loss: 0.010
# [22] train_acc: 0.656 train_loss: 0.010
# [22] test_acc: 0.660 test_loss: 0.010
# [23] train_acc: 0.662 train_loss: 0.010
# [23] test_acc: 0.664 test_loss: 0.010
# [24] train_acc: 0.665 train_loss: 0.010
# [24] test_acc: 0.676 test_loss: 0.010
# [25] train_acc: 0.675 train_loss: 0.010
# [25] test_acc: 0.673 test_loss: 0.010
# [26] train_acc: 0.675 train_loss: 0.010
# [26] test_acc: 0.676 test_loss: 0.010
# [27] train_acc: 0.681 train_loss: 0.009
# [27] test_acc: 0.674 test_loss: 0.010
# [28] train_acc: 0.676 train_loss: 0.009
# [28] test_acc: 0.687 test_loss: 0.010
# [29] train_acc: 0.688 train_loss: 0.009
# [29] test_acc: 0.683 test_loss: 0.010
# [30] train_acc: 0.691 train_loss: 0.009
# [30] test_acc: 0.689 test_loss: 0.009
# [31] train_acc: 0.687 train_loss: 0.009
# [31] test_acc: 0.684 test_loss: 0.009
# [32] train_acc: 0.694 train_loss: 0.009
# [32] test_acc: 0.697 test_loss: 0.009
# [33] train_acc: 0.695 train_loss: 0.009
# [33] test_acc: 0.690 test_loss: 0.009
# [34] train_acc: 0.699 train_loss: 0.009
# [34] test_acc: 0.696 test_loss: 0.009
# [35] train_acc: 0.701 train_loss: 0.009
# [35] test_acc: 0.699 test_loss: 0.009
# [36] train_acc: 0.704 train_loss: 0.009
# [36] test_acc: 0.698 test_loss: 0.009
# [37] train_acc: 0.705 train_loss: 0.009
# [37] test_acc: 0.698 test_loss: 0.009
# [38] train_acc: 0.712 train_loss: 0.009
# [38] test_acc: 0.703 test_loss: 0.009
# [39] train_acc: 0.707 train_loss: 0.009
# [39] test_acc: 0.707 test_loss: 0.009
# [40] train_acc: 0.715 train_loss: 0.009
# [40] test_acc: 0.707 test_loss: 0.009
# [41] train_acc: 0.714 train_loss: 0.009
# [41] test_acc: 0.705 test_loss: 0.009
# [42] train_acc: 0.707 train_loss: 0.009
# [42] test_acc: 0.708 test_loss: 0.009
# [43] train_acc: 0.716 train_loss: 0.009
# [43] test_acc: 0.703 test_loss: 0.009
# [44] train_acc: 0.717 train_loss: 0.009
# [44] test_acc: 0.711 test_loss: 0.009
# [45] train_acc: 0.712 train_loss: 0.009
# [45] test_acc: 0.712 test_loss: 0.009
# [46] train_acc: 0.720 train_loss: 0.009
# [46] test_acc: 0.706 test_loss: 0.009
# [47] train_acc: 0.728 train_loss: 0.009
# [47] test_acc: 0.709 test_loss: 0.009
# [48] train_acc: 0.714 train_loss: 0.009
# [48] test_acc: 0.718 test_loss: 0.009
# [49] train_acc: 0.724 train_loss: 0.009
# [49] test_acc: 0.719 test_loss: 0.009
# [50] train_acc: 0.727 train_loss: 0.009
# [50] test_acc: 0.719 test_loss: 0.009
# [51] train_acc: 0.730 train_loss: 0.009
# [51] test_acc: 0.724 test_loss: 0.009
# [52] train_acc: 0.730 train_loss: 0.009
# [52] test_acc: 0.717 test_loss: 0.009
# [53] train_acc: 0.732 train_loss: 0.009
# [53] test_acc: 0.728 test_loss: 0.009
# [54] train_acc: 0.729 train_loss: 0.009
# [54] test_acc: 0.729 test_loss: 0.009
# [55] train_acc: 0.735 train_loss: 0.008
# [55] test_acc: 0.732 test_loss: 0.009
# [56] train_acc: 0.734 train_loss: 0.009
# [56] test_acc: 0.729 test_loss: 0.008
# [57] train_acc: 0.736 train_loss: 0.008
# [57] test_acc: 0.734 test_loss: 0.009
# [58] train_acc: 0.739 train_loss: 0.008
# [58] test_acc: 0.734 test_loss: 0.009
# [59] train_acc: 0.740 train_loss: 0.008
# [59] test_acc: 0.742 test_loss: 0.008
# [60] train_acc: 0.746 train_loss: 0.008
# [60] test_acc: 0.737 test_loss: 0.009
# [61] train_acc: 0.741 train_loss: 0.008
# [61] test_acc: 0.732 test_loss: 0.008
# [62] train_acc: 0.745 train_loss: 0.008
# [62] test_acc: 0.740 test_loss: 0.008
# [63] train_acc: 0.745 train_loss: 0.008
# [63] test_acc: 0.746 test_loss: 0.008
# [64] train_acc: 0.749 train_loss: 0.008
# [64] test_acc: 0.734 test_loss: 0.008
# [65] train_acc: 0.751 train_loss: 0.008
# [65] test_acc: 0.744 test_loss: 0.008
# [66] train_acc: 0.749 train_loss: 0.008
# [66] test_acc: 0.736 test_loss: 0.009
# [67] train_acc: 0.749 train_loss: 0.008
# [67] test_acc: 0.733 test_loss: 0.008
# [68] train_acc: 0.750 train_loss: 0.008
# [68] test_acc: 0.746 test_loss: 0.008
# [69] train_acc: 0.751 train_loss: 0.008
# [69] test_acc: 0.739 test_loss: 0.008
# [70] train_acc: 0.751 train_loss: 0.008
# [70] test_acc: 0.745 test_loss: 0.008
# [71] train_acc: 0.755 train_loss: 0.008
# [71] test_acc: 0.755 test_loss: 0.008
# [72] train_acc: 0.752 train_loss: 0.008
# [72] test_acc: 0.742 test_loss: 0.008
# [73] train_acc: 0.756 train_loss: 0.008
# [73] test_acc: 0.749 test_loss: 0.008
# [74] train_acc: 0.757 train_loss: 0.008
# [74] test_acc: 0.751 test_loss: 0.008
# [75] train_acc: 0.754 train_loss: 0.008
# [75] test_acc: 0.746 test_loss: 0.008
# [76] train_acc: 0.751 train_loss: 0.008
# [76] test_acc: 0.748 test_loss: 0.008
# [77] train_acc: 0.755 train_loss: 0.008
# [77] test_acc: 0.755 test_loss: 0.008
# [78] train_acc: 0.763 train_loss: 0.008
# [78] test_acc: 0.756 test_loss: 0.008
# [79] train_acc: 0.762 train_loss: 0.008
# [79] test_acc: 0.749 test_loss: 0.008
# [80] train_acc: 0.761 train_loss: 0.008
# [80] test_acc: 0.758 test_loss: 0.008
# [81] train_acc: 0.760 train_loss: 0.008
# [81] test_acc: 0.757 test_loss: 0.008
# [82] train_acc: 0.763 train_loss: 0.008
# [82] test_acc: 0.757 test_loss: 0.008
# [83] train_acc: 0.764 train_loss: 0.008
# [83] test_acc: 0.753 test_loss: 0.008
# [84] train_acc: 0.766 train_loss: 0.008
# [84] test_acc: 0.756 test_loss: 0.008
# [85] train_acc: 0.767 train_loss: 0.008
# [85] test_acc: 0.758 test_loss: 0.008
# [86] train_acc: 0.770 train_loss: 0.008
# [86] test_acc: 0.766 test_loss: 0.008
# [87] train_acc: 0.770 train_loss: 0.008
# [87] test_acc: 0.765 test_loss: 0.008
# [88] train_acc: 0.770 train_loss: 0.008
# [88] test_acc: 0.760 test_loss: 0.008
# [89] train_acc: 0.772 train_loss: 0.008
# [89] test_acc: 0.762 test_loss: 0.008
# [90] train_acc: 0.769 train_loss: 0.008
# [90] test_acc: 0.758 test_loss: 0.008
# [91] train_acc: 0.769 train_loss: 0.008
# [91] test_acc: 0.765 test_loss: 0.008
# [92] train_acc: 0.777 train_loss: 0.008
# [92] test_acc: 0.760 test_loss: 0.008
# [93] train_acc: 0.768 train_loss: 0.008
# [93] test_acc: 0.761 test_loss: 0.008
# [94] train_acc: 0.776 train_loss: 0.008
# [94] test_acc: 0.758 test_loss: 0.008
# [95] train_acc: 0.776 train_loss: 0.008
# [95] test_acc: 0.767 test_loss: 0.008
# [96] train_acc: 0.772 train_loss: 0.008
# [96] test_acc: 0.769 test_loss: 0.008
# [97] train_acc: 0.778 train_loss: 0.007
# [97] test_acc: 0.766 test_loss: 0.008
# [98] train_acc: 0.778 train_loss: 0.008
# [98] test_acc: 0.768 test_loss: 0.008
# [99] train_acc: 0.778 train_loss: 0.007
# [99] test_acc: 0.775 test_loss: 0.008
# [100] train_acc: 0.777 train_loss: 0.008
# [100] test_acc: 0.767 test_loss: 0.008
# Finished Training
# "for epoch in range(100):  # loop over the dataset multiple times\n    running_loss = 0.0\n    for i in range(int(EMONEW.lenght()/BATCH_SIZE)):\n        net.train()\n        # get the inputs\n        inputs, labels = EMONEW.get_batch(BATCH_SIZE)\n        inputs = torch.Tensor(inputs).to(device)/255\n        labels = torch.Tensor(labels).max(1)[1].type(torch.LongTensor).to(device)\n        # zero the parameter gradients\n        optimizer.zero_grad()\n\n        # forward + backward + optimize\n        outputs = net(inputs)\n        loss = criterion(outputs, labels)\n        loss.backward()\n\n        # print statistics\n        running_loss += loss.item()\n        if i%10 == 9:\n            print('[%d] loss: %.3f' %(epoch + 1, running_loss / (10*BATCH_SIZE)))\n            running_loss = 0.0\n            \n        optimizer.step()\n        \n    test_loss = 0\n    correct = 0\n    with torch.no_grad():\n        for i in range(int(EMONEW.lenght(False)/BATCH_SIZE)):\n            inputs, labels = EMONEW.get_batch(BATCH_SIZE, False)\n            inputs = torch.Tensor(inputs).to(device)/255\n            outputs = net(inputs)\n            labels = torch.Tensor(labels).max(1)[1].type(torch.LongTensor).to(device)\n            test_loss += criterion(outputs, labels) # sum up batch loss\n            pred = outputs.max(1, keepdim=True)[1] # get the index of the max log-probability\n            correct += pred.eq(labels.view_as(pred)).sum().item()\n\n    test_loss /= EMONEW.lenght(False)\n    print('\n[{}] Test set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(epoch+1,\n        test_loss, correct, EMONEW.lenght(False),\n        100. * correct / EMONEW.lenght(False)))\n    S_gabor_test_acc.append(correct / EMONEW.lenght(False))\nprint('Finished Training')"

# %%
class convNet(nn.Module):
    def __init__(self):
        super(convNet, self).__init__()
        self.c0 = nn.Conv2d(3, 32, kernel_size=(5,5), stride=1)
        self.c1 = nn.Conv2d(32, 64, kernel_size=(5,5), stride=1)
        self.c2 = nn.Conv2d(64, 128, kernel_size=(3,3), stride=1)
        self.c3 = nn.Conv2d(128, 128, kernel_size=(3,3), stride=1)
        self.c4 = nn.Conv2d(128, 128, kernel_size=(3,3), stride=1)
        self.fc1 = nn.Linear(128*5*5, 128)
        self.fc2 = nn.Linear(128, 128)
        self.fc3 = nn.Linear(128,2)

    def forward(self, x):
        x = F.max_pool2d(F.relu(self.c0(x)), kernel_size=2)
        x = nn.Dropout2d()(x)
        x = F.max_pool2d(F.relu(self.c1(x)), kernel_size=2)
        x = nn.Dropout2d()(x)
        x = F.max_pool2d(F.relu(self.c2(x)), kernel_size=2)
        x = nn.Dropout2d()(x)
        x = F.max_pool2d(F.relu(self.c3(x)), kernel_size=2)
        x = nn.Dropout2d()(x)
        x = F.max_pool2d(F.relu(self.c4(x)), kernel_size=2)
        x = nn.Dropout2d()(x)
        x = x.view(-1, 128*5*5)
        x = F.relu(self.fc1(x))
        x = nn.Dropout()(x)
        x = F.relu(self.fc2(x))
        x = nn.Dropout()(x)
        x = self.fc3(x)
        return x

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
net = convNet().to(device)
net.apply(weights_init)
print(net)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters())
# Out:
# cuda:0
# convNet(
#   (c0): Conv2d(3, 32, kernel_size=(5, 5), stride=(1, 1))
#   (c1): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1))
#   (c2): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1))
#   (c3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#   (c4): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#   (fc1): Linear(in_features=3200, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=128, bias=True)
#   (fc3): Linear(in_features=128, out_features=2, bias=True)
# )

# %%
for epoch in range(100):

    running_loss = 0.0
    correct = 0
    net.train()
    for i, data in enumerate(train, 0):
        # get the inputs
        inputs, labels = data['image'], data['target']

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = net(inputs.to(device))
        loss = criterion(outputs, labels.to(device))
        loss.backward()
        optimizer.step()
        pred = outputs.max(1, keepdim=True)[1].to('cpu')
        correct += pred.eq(labels.view_as(pred)).sum().item()

        # print statistics
        running_loss += loss.item()
    print('[%d] train_acc: %.3f train_loss: %.3f' %(epoch + 1, correct/len(train_set), running_loss/len(train_set))) 
    convnet_acc_train.append(correct/len(train_set))
    convnet_loss_train.append(running_loss/len(train_set)) 
    
    running_loss = 0.0
    correct = 0
    with torch.no_grad():
        net.eval()
        for i, data in enumerate(test, 0):
            # get the inputs
            inputs, labels = data['image'], data['target']

            # forward + backward + optimize
            outputs = net(inputs.to(device))
            loss = criterion(outputs, labels.to(device))

            pred = outputs.max(1, keepdim=True)[1].to('cpu')
            correct += pred.eq(labels.view_as(pred)).sum().item()
            running_loss += loss.item()
    print('[%d] test_acc: %.3f test_loss: %.3f' %(epoch + 1, correct/len(test_set), running_loss/len(test_set)))
    convnet_acc_test.append(correct/len(test_set))
    convnet_loss_test.append(running_loss/len(test_set))      

print('Finished Training')

np.save('convnet_acc_train.npy', convnet_acc_train)
np.save('convnet_loss_train.npy', convnet_loss_train)
np.save('convnet_acc_test.npy', convnet_acc_test)
np.save('convnet_loss_test.npy', convnet_loss_test)
# Out:
# [1] train_acc: 0.516 train_loss: 0.011
# [1] test_acc: 0.509 test_loss: 0.011
# [2] train_acc: 0.507 train_loss: 0.011
# [2] test_acc: 0.510 test_loss: 0.011
# [3] train_acc: 0.517 train_loss: 0.011
# [3] test_acc: 0.513 test_loss: 0.011
# [4] train_acc: 0.517 train_loss: 0.011
# [4] test_acc: 0.521 test_loss: 0.011
# [5] train_acc: 0.517 train_loss: 0.011
# [5] test_acc: 0.532 test_loss: 0.011
# [6] train_acc: 0.550 train_loss: 0.011
# [6] test_acc: 0.544 test_loss: 0.011
# [7] train_acc: 0.559 train_loss: 0.011
# [7] test_acc: 0.567 test_loss: 0.011
# [8] train_acc: 0.576 train_loss: 0.011
# [8] test_acc: 0.593 test_loss: 0.011
# [9] train_acc: 0.595 train_loss: 0.011
# [9] test_acc: 0.604 test_loss: 0.011
# [10] train_acc: 0.605 train_loss: 0.010
# [10] test_acc: 0.618 test_loss: 0.010
# [11] train_acc: 0.624 train_loss: 0.010
# [11] test_acc: 0.613 test_loss: 0.011
# [12] train_acc: 0.624 train_loss: 0.010
# [12] test_acc: 0.625 test_loss: 0.010
# [13] train_acc: 0.628 train_loss: 0.010
# [13] test_acc: 0.634 test_loss: 0.010
# [14] train_acc: 0.628 train_loss: 0.010
# [14] test_acc: 0.640 test_loss: 0.010
# [15] train_acc: 0.639 train_loss: 0.010
# [15] test_acc: 0.636 test_loss: 0.010
# [16] train_acc: 0.646 train_loss: 0.010
# [16] test_acc: 0.652 test_loss: 0.010
# [17] train_acc: 0.647 train_loss: 0.010
# [17] test_acc: 0.656 test_loss: 0.010
# [18] train_acc: 0.647 train_loss: 0.010
# [18] test_acc: 0.654 test_loss: 0.010
# [19] train_acc: 0.658 train_loss: 0.010
# [19] test_acc: 0.656 test_loss: 0.010
# [20] train_acc: 0.654 train_loss: 0.010
# [20] test_acc: 0.659 test_loss: 0.010
# [21] train_acc: 0.662 train_loss: 0.010
# [21] test_acc: 0.660 test_loss: 0.010
# [22] train_acc: 0.660 train_loss: 0.010
# [22] test_acc: 0.662 test_loss: 0.010
# [23] train_acc: 0.658 train_loss: 0.010
# [23] test_acc: 0.658 test_loss: 0.010
# [24] train_acc: 0.667 train_loss: 0.010
# [24] test_acc: 0.649 test_loss: 0.010
# [25] train_acc: 0.662 train_loss: 0.010
# [25] test_acc: 0.662 test_loss: 0.010
# [26] train_acc: 0.663 train_loss: 0.010
# [26] test_acc: 0.657 test_loss: 0.010
# [27] train_acc: 0.667 train_loss: 0.010
# [27] test_acc: 0.661 test_loss: 0.010
# [28] train_acc: 0.662 train_loss: 0.010
# [28] test_acc: 0.672 test_loss: 0.010
# [29] train_acc: 0.666 train_loss: 0.010
# [29] test_acc: 0.668 test_loss: 0.010
# [30] train_acc: 0.670 train_loss: 0.010
# [30] test_acc: 0.660 test_loss: 0.010
# [31] train_acc: 0.668 train_loss: 0.010
# [31] test_acc: 0.664 test_loss: 0.010
# [32] train_acc: 0.674 train_loss: 0.010
# [32] test_acc: 0.674 test_loss: 0.010
# [33] train_acc: 0.674 train_loss: 0.010
# [33] test_acc: 0.673 test_loss: 0.010
# [34] train_acc: 0.685 train_loss: 0.009
# [34] test_acc: 0.670 test_loss: 0.010
# [35] train_acc: 0.679 train_loss: 0.009
# [35] test_acc: 0.680 test_loss: 0.009
# [36] train_acc: 0.673 train_loss: 0.010
# [36] test_acc: 0.674 test_loss: 0.010
# [37] train_acc: 0.682 train_loss: 0.009
# [37] test_acc: 0.669 test_loss: 0.010
# [38] train_acc: 0.684 train_loss: 0.009
# [38] test_acc: 0.669 test_loss: 0.010
# [39] train_acc: 0.681 train_loss: 0.009
# [39] test_acc: 0.678 test_loss: 0.010
# [40] train_acc: 0.676 train_loss: 0.009
# [40] test_acc: 0.675 test_loss: 0.010
# [41] train_acc: 0.682 train_loss: 0.009
# [41] test_acc: 0.688 test_loss: 0.009
# [42] train_acc: 0.687 train_loss: 0.009
# [42] test_acc: 0.678 test_loss: 0.010
# [43] train_acc: 0.688 train_loss: 0.009
# [43] test_acc: 0.674 test_loss: 0.010
# [44] train_acc: 0.688 train_loss: 0.009
# [44] test_acc: 0.683 test_loss: 0.010
# [45] train_acc: 0.690 train_loss: 0.009
# [45] test_acc: 0.687 test_loss: 0.009
# [46] train_acc: 0.687 train_loss: 0.009
# [46] test_acc: 0.694 test_loss: 0.009
# [47] train_acc: 0.692 train_loss: 0.009
# [47] test_acc: 0.679 test_loss: 0.010
# [48] train_acc: 0.691 train_loss: 0.009
# [48] test_acc: 0.694 test_loss: 0.009
# [49] train_acc: 0.696 train_loss: 0.009
# [49] test_acc: 0.691 test_loss: 0.009
# [50] train_acc: 0.694 train_loss: 0.009
# [50] test_acc: 0.688 test_loss: 0.009
# [51] train_acc: 0.696 train_loss: 0.009
# [51] test_acc: 0.683 test_loss: 0.009
# [52] train_acc: 0.691 train_loss: 0.009
# [52] test_acc: 0.694 test_loss: 0.009
# [53] train_acc: 0.704 train_loss: 0.009
# [53] test_acc: 0.694 test_loss: 0.009
# [54] train_acc: 0.700 train_loss: 0.009
# [54] test_acc: 0.691 test_loss: 0.009
# [55] train_acc: 0.701 train_loss: 0.009
# [55] test_acc: 0.702 test_loss: 0.009
# [56] train_acc: 0.701 train_loss: 0.009
# [56] test_acc: 0.693 test_loss: 0.009
# [57] train_acc: 0.704 train_loss: 0.009
# [57] test_acc: 0.695 test_loss: 0.009
# [58] train_acc: 0.703 train_loss: 0.009
# [58] test_acc: 0.701 test_loss: 0.009
# [59] train_acc: 0.709 train_loss: 0.009
# [59] test_acc: 0.706 test_loss: 0.009
# [60] train_acc: 0.706 train_loss: 0.009
# [60] test_acc: 0.700 test_loss: 0.009
# [61] train_acc: 0.710 train_loss: 0.009
# [61] test_acc: 0.709 test_loss: 0.009
# [62] train_acc: 0.708 train_loss: 0.009
# [62] test_acc: 0.707 test_loss: 0.009
# [63] train_acc: 0.716 train_loss: 0.009
# [63] test_acc: 0.699 test_loss: 0.009
# [64] train_acc: 0.713 train_loss: 0.009
# [64] test_acc: 0.711 test_loss: 0.009
# [65] train_acc: 0.709 train_loss: 0.009
# [65] test_acc: 0.712 test_loss: 0.009
# [66] train_acc: 0.721 train_loss: 0.009
# [66] test_acc: 0.698 test_loss: 0.009
# [67] train_acc: 0.722 train_loss: 0.009
# [67] test_acc: 0.700 test_loss: 0.009
# [68] train_acc: 0.723 train_loss: 0.009
# [68] test_acc: 0.714 test_loss: 0.009
# [69] train_acc: 0.720 train_loss: 0.009
# [69] test_acc: 0.707 test_loss: 0.009
# [70] train_acc: 0.717 train_loss: 0.009
# [70] test_acc: 0.711 test_loss: 0.009
# [71] train_acc: 0.727 train_loss: 0.009
# [71] test_acc: 0.718 test_loss: 0.009
# [72] train_acc: 0.726 train_loss: 0.009
# [72] test_acc: 0.720 test_loss: 0.009
# [73] train_acc: 0.708 train_loss: 0.009
# [73] test_acc: 0.711 test_loss: 0.009
# [74] train_acc: 0.729 train_loss: 0.009
# [74] test_acc: 0.703 test_loss: 0.009
# [75] train_acc: 0.727 train_loss: 0.009
# [75] test_acc: 0.727 test_loss: 0.009
# [76] train_acc: 0.734 train_loss: 0.009
# [76] test_acc: 0.719 test_loss: 0.009
# [77] train_acc: 0.735 train_loss: 0.008
# [77] test_acc: 0.714 test_loss: 0.009
# [78] train_acc: 0.731 train_loss: 0.009
# [78] test_acc: 0.726 test_loss: 0.009
# [79] train_acc: 0.723 train_loss: 0.009
# [79] test_acc: 0.735 test_loss: 0.009
# [80] train_acc: 0.730 train_loss: 0.009
# [80] test_acc: 0.733 test_loss: 0.009
# [81] train_acc: 0.741 train_loss: 0.008
# [81] test_acc: 0.702 test_loss: 0.009
# [82] train_acc: 0.729 train_loss: 0.008
# [82] test_acc: 0.732 test_loss: 0.009
# [83] train_acc: 0.737 train_loss: 0.008
# [83] test_acc: 0.728 test_loss: 0.009
# [84] train_acc: 0.742 train_loss: 0.008
# [84] test_acc: 0.734 test_loss: 0.009
# [85] train_acc: 0.734 train_loss: 0.008
# [85] test_acc: 0.713 test_loss: 0.009
# [86] train_acc: 0.737 train_loss: 0.008
# [86] test_acc: 0.732 test_loss: 0.008
# [87] train_acc: 0.737 train_loss: 0.008
# [87] test_acc: 0.715 test_loss: 0.009
# [88] train_acc: 0.740 train_loss: 0.008
# [88] test_acc: 0.740 test_loss: 0.008
# [89] train_acc: 0.738 train_loss: 0.008
# [89] test_acc: 0.734 test_loss: 0.009
# [90] train_acc: 0.738 train_loss: 0.008
# [90] test_acc: 0.723 test_loss: 0.009
# [91] train_acc: 0.741 train_loss: 0.008
# [91] test_acc: 0.736 test_loss: 0.008
# [92] train_acc: 0.744 train_loss: 0.008
# [92] test_acc: 0.735 test_loss: 0.008
# [93] train_acc: 0.747 train_loss: 0.008
# [93] test_acc: 0.728 test_loss: 0.009
# [94] train_acc: 0.748 train_loss: 0.008
# [94] test_acc: 0.729 test_loss: 0.008
# [95] train_acc: 0.744 train_loss: 0.008
# [95] test_acc: 0.732 test_loss: 0.008
# [96] train_acc: 0.747 train_loss: 0.008
# [96] test_acc: 0.742 test_loss: 0.008
# [97] train_acc: 0.751 train_loss: 0.008
# [97] test_acc: 0.735 test_loss: 0.008
# [98] train_acc: 0.748 train_loss: 0.008
# [98] test_acc: 0.744 test_loss: 0.008
# [99] train_acc: 0.746 train_loss: 0.008
# [99] test_acc: 0.741 test_loss: 0.008
# [100] train_acc: 0.746 train_loss: 0.008
# [100] test_acc: 0.743 test_loss: 0.008
# Finished Training

# %%
one_layer_gnet_acc_train = np.load('one_layer_gnet_acc_train.npy')

# %%
convnet_acc_train = np.load('convnet_acc_train.npy')
convnet_acc_test = np.load('convnet_acc_test.npy')

# %%
plt.plot(convnet_acc_test, label = 'conv')
plt.plot(one_layer_gnet_acc_test, label = 'Gnet')
plt.legend(loc = 0)
plt.title('test accuracy')
plt.show()
plt.plot(convnet_acc_train, label = 'conv')
plt.plot(one_layer_gnet_acc_train, label = 'Gnet')
plt.legend(loc = 0)
plt.title('train accuracy')
plt.show()

# %%
class GaborNet_two_layer(nn.Module):
    def __init__(self):
        super(GaborNet_two_layer, self).__init__()
        self.g1 = GaborConv2d(3, 32, kernel_size=(15,15), stride=1)
        self.g2 = GaborConv2d(32, 64, kernel_size=(15,15), stride=1)
        self.c2 = nn.Conv2d(64, 128, kernel_size=(3,3), stride=1)
        self.c3 = nn.Conv2d(128, 128, kernel_size=(3,3), stride=1)
        self.c4 = nn.Conv2d(128, 128, kernel_size=(3,3), stride=1)
        self.fc1 = nn.Linear(128*4*4, 128)
        self.fc2 = nn.Linear(128, 128)
        self.fc3 = nn.Linear(128,2)

    def forward(self, x):
        x = F.max_pool2d(F.relu(self.g1(x)), kernel_size=2)
        x = nn.Dropout2d()(x)
        x = F.max_pool2d(F.relu(self.g2(x)), kernel_size=2)
        x = nn.Dropout2d()(x)
        x = F.max_pool2d(F.relu(self.c2(x)), kernel_size=2)
        x = nn.Dropout2d()(x)
        x = F.max_pool2d(F.relu(self.c3(x)), kernel_size=2)
        x = nn.Dropout2d()(x)
        x = F.max_pool2d(F.relu(self.c4(x)), kernel_size=2)
        x = nn.Dropout2d()(x)
        print(x.shape)
        x = x.view(-1, 128*4*4)
        x = F.relu(self.fc1(x))
        x = nn.Dropout()(x)
        x = F.relu(self.fc2(x))
        x = nn.Dropout()(x)
        x = self.fc3(x)
        return x

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
net = GaborNet_two_layer().to(device)
net.apply(weights_init)
print(net)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters())
# Out:
# cuda:0
# GaborNet_two_layer(
#   (g1): GaborConv2d(3, 32, kernel_size=(15, 15), stride=(1, 1), bias=False)
#   (g2): GaborConv2d(32, 64, kernel_size=(15, 15), stride=(1, 1), bias=False)
#   (c2): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1))
#   (c3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#   (c4): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#   (fc1): Linear(in_features=2048, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=128, bias=True)
#   (fc3): Linear(in_features=128, out_features=2, bias=True)
# )

# %%
net(torch.normal(torch.Tensor(1,3,256,256)).to(device))
# Out:
# torch.Size([1, 128, 4, 4])
# tensor([[nan, nan]], device='cuda:0', grad_fn=<ThAddmmBackward>)
