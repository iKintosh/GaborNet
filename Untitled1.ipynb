# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
alexnet_data = []
gabornet_data = []

with open('alexnet_train.txt', 'r') as f:
    for line in f:
        line = line.replace(')', '').replace("(", '').split()
        alexnet_data.append(line)
        
with open('gabornet_train_.txt', 'r') as f:
    for line in f:
        line = line.replace(')', '').replace("(", '').split()
        gabornet_data.append(line)

# %%
alexnet_data = np.array(alexnet_data)
gabornet_data = np.array(gabornet_data)

# %%
alexnet_data[0]
# Out:
# array(['Epoch:', '[0][0/5005]', 'Time', '5.058', '5.058', 'Data', '2.695',
#        '2.695', 'Loss', '6.9074', '6.9074', 'Acc@1', '0.000', '0.000',
#        'Acc@5', '0.000', '0.000'], dtype='<U15')

# %%
num = 5005
alex_mean = []
gabor_mean = []
for i in range(90):
    alex_mean.append(np.sum(alexnet_data[i*num:i*num+num, -4].astype(np.float))/num)
    gabor_mean.append(np.sum(gabornet_data[i*num:i*num+num, -4].astype(np.float))/num)

# %%
len(gabornet_data)/num
# Out:
# 90.0

# %%
plt.figure(figsize=(10,5))
plt.plot(alex_mean, label = 'Alexnet')
plt.plot(gabor_mean, label = 'Gabor Alexnet')
plt.legend()
plt.title('Train on IMAGENET')
plt.ylabel('top1')
plt.xlabel('epoch')
plt.grid()
plt.show()

# %%
alex_mean
# Out:
# [0.3219688311688312,
#  8.43852067932068,
#  19.2592015984016,
#  25.458266733266733,
#  29.18307972027972,
#  31.95469270729271,
#  33.89429370629371,
#  35.395555644355646,
#  36.6110007992008,
#  37.64055224775225,
#  38.48937062937063,
#  39.23148631368631,
#  39.876197002996996,
#  40.34414865134865,
#  40.996309090909094,
#  41.34386193806194,
#  41.853444355644356,
#  42.20289750249751,
#  42.46353806193806,
#  42.68154425574425,
#  43.05805234765235,
#  43.33222077922078,
#  43.782036363636365,
#  43.927467932067934,
#  44.101390009990006,
#  44.37961698301699,
#  44.570273726273726,
#  44.76236803196803,
#  44.86018401598402,
#  45.094641158841156,
#  51.06854965034965,
#  53.912947652347654,
#  55.065944855144856,
#  55.646676123876134,
#  56.3862955044955,
#  56.89974425574425,
#  57.28753946053946,
#  57.77964735264735,
#  58.091540459540454,
#  58.5333050949051,
#  58.885397002997,
#  59.19997702297702,
#  59.484573426573434,
#  59.847439960039964,
#  59.98491608391608,
# ...

# %%
import os
import piexif
for root,folders,files in os.walk('C:\Projects\IMAGENET'):
    for file in files:
        if '.JPEG' in file:
            try:
                piexif.remove(os.path.join(root,file))
            except UnboundLocalError as err:
                print('!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!')
                print(err)
                print(file)
                print('!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!')
                continue
    print(root)
# Out:
# C:\Projects\IMAGENET
# C:\Projects\IMAGENET\train
# C:\Projects\IMAGENET\train\n01440764
# C:\Projects\IMAGENET\train\n01443537
# C:\Projects\IMAGENET\train\n01484850
# C:\Projects\IMAGENET\train\n01491361
# C:\Projects\IMAGENET\train\n01494475
# C:\Projects\IMAGENET\train\n01496331
# C:\Projects\IMAGENET\train\n01498041
# C:\Projects\IMAGENET\train\n01514668
# C:\Projects\IMAGENET\train\n01514859
# C:\Projects\IMAGENET\train\n01518878
# C:\Projects\IMAGENET\train\n01530575
# C:\Projects\IMAGENET\train\n01531178
# C:\Projects\IMAGENET\train\n01532829
# C:\Projects\IMAGENET\train\n01534433
# C:\Projects\IMAGENET\train\n01537544
# C:\Projects\IMAGENET\train\n01558993
# C:\Projects\IMAGENET\train\n01560419
# C:\Projects\IMAGENET\train\n01580077
# C:\Projects\IMAGENET\train\n01582220
# C:\Projects\IMAGENET\train\n01592084
# C:\Projects\IMAGENET\train\n01601694
# C:\Projects\IMAGENET\train\n01608432
# C:\Projects\IMAGENET\train\n01614925
# C:\Projects\IMAGENET\train\n01616318
# ...

# %%
im = Image.open(infile)
            im.thumbnail(size, Image.ANTIALIAS)
            im.save(outfile, "JPEG")

# %%
import os
from PIL import Image
size = (224, 224)
for root,folders,files in os.walk('C:\Projects\IMAGENET'):
    for file in files:
        if '.JPEG' in file:
            try:
                im = Image.open(os.path.join(root,file))
                im = im.resize(size)
                im.save(os.path.join(root,file), "JPEG")
            except IOError as err:
                print('!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!')
                print(err)
                print(file)
                print('!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!')
                continue
    print(root)
# Out:
# C:\Projects\IMAGENET
# C:\Projects\IMAGENET\train
# C:\Projects\IMAGENET\train\n01440764
# C:\Projects\IMAGENET\train\n01443537
# C:\Projects\IMAGENET\train\n01484850
# C:\Projects\IMAGENET\train\n01491361
# C:\Projects\IMAGENET\train\n01494475
# C:\Projects\IMAGENET\train\n01496331
# C:\Projects\IMAGENET\train\n01498041
# C:\Projects\IMAGENET\train\n01514668
# C:\Projects\IMAGENET\train\n01514859
# C:\Projects\IMAGENET\train\n01518878
# C:\Projects\IMAGENET\train\n01530575
# C:\Projects\IMAGENET\train\n01531178
# C:\Projects\IMAGENET\train\n01532829
# C:\Projects\IMAGENET\train\n01534433
# C:\Projects\IMAGENET\train\n01537544
# C:\Projects\IMAGENET\train\n01558993
# C:\Projects\IMAGENET\train\n01560419
# C:\Projects\IMAGENET\train\n01580077
# C:\Projects\IMAGENET\train\n01582220
# C:\Projects\IMAGENET\train\n01592084
# C:\Projects\IMAGENET\train\n01601694
# C:\Projects\IMAGENET\train\n01608432
# C:\Projects\IMAGENET\train\n01614925
# C:\Projects\IMAGENET\train\n01616318
# ...

# %%
np.load('_AffectiveNet_new_init_one_layer_gnet_acc_test.npy').shape
# Out:
# (70,)

# %%
plt.plot(np.load('_AffectiveNet_convnet_acc_test.npy'), label = 'conv')
plt.plot(np.load('_AffectiveNet_new_init_one_layer_gnet_acc_test.npy'), label = 'Gnet')
plt.legend(loc = 0)
plt.title('test accuracy')
plt.show()
